# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-86e3617a-9627-41ab-bed5-1b7f2af1107c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86e3617a-9627-41ab-bed5-1b7f2af1107c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data=pd.read_csv("/content/mark 01.csv")

# %%
data.head(53)
# Out:
#    Reg. Number        Stud. Name Unnamed: 2 Grade1 Grade2 Grade3 Grade4  \
# 0     9.10E+11    AATHAVAJAYANTH        A S     A+      O      O      B
# 1     9.10E+11           ABINAYA          P      B      A      O     B+
# 2     9.10E+11       AJITH KUMAR          K     A+      O      O     A+
# 3     9.10E+11           AKSHAYA          S      A      O      O      A
# 4     9.10E+11          AKSHITHA        V A      A      O      O     B+
# 5     9.10E+11               ANU          M      A     A+      O      A
# 6     9.10E+11        ARULSELVAN          M     B+      O      O      A
# 7     9.10E+11              ARUN          S     B+     A+     A+     B+
# 8     9.10E+11        ARUN KUMAR          M      A     A+     A+      A
# 9     9.10E+11      BALAKRISHNAN          B      A      O      O      A
# 10    9.10E+11      DEEPTHIPRIYA          R     A+      O      O     A+
# 11    9.10E+11         DHARSHIKA        R S     A+     A+     A+     A+
# ...

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()
data.head(53)
# Out:
#    Reg. Number        Stud. Name Unnamed: 2 Grade1 Grade2 Grade3 Grade4  \
# 0     9.10E+11    AATHAVAJAYANTH        A S     A+      O      O      B
# 1     9.10E+11           ABINAYA          P      B      A      O     B+
# 2     9.10E+11       AJITH KUMAR          K     A+      O      O     A+
# 3     9.10E+11           AKSHAYA          S      A      O      O      A
# 4     9.10E+11          AKSHITHA        V A      A      O      O     B+
# 5     9.10E+11               ANU          M      A     A+      O      A
# 6     9.10E+11        ARULSELVAN          M     B+      O      O      A
# 7     9.10E+11              ARUN          S     B+     A+     A+     B+
# 8     9.10E+11        ARUN KUMAR          M      A     A+     A+      A
# 9     9.10E+11      BALAKRISHNAN          B      A      O      O      A
# 10    9.10E+11      DEEPTHIPRIYA          R     A+      O      O     A+
# 11    9.10E+11         DHARSHIKA        R S     A+     A+     A+     A+
# ...

# %%
import numpy as np
df=pd.DataFrame(data)
df["GP1"]=np.where((df.Grade1=='U'),
           4,np.where((df.Grade1=='B'),
                    6,np.where((df.Grade1=='B+'),
                    7,np.where((df.Grade1=='A'),
                     8,np.where((df.Grade1=='A+'),
                      9,np.where((df.Grade1=='O'),
                      10,5))))))

# %%
data.head(53)
# Out:
#    Reg. Number        Stud. Name Unnamed: 2 Grade1 Grade2 Grade3 Grade4  \
# 0     9.10E+11    AATHAVAJAYANTH        A S     A+      O      O      B
# 1     9.10E+11           ABINAYA          P      B      A      O     B+
# 2     9.10E+11       AJITH KUMAR          K     A+      O      O     A+
# 3     9.10E+11           AKSHAYA          S      A      O      O      A
# 4     9.10E+11          AKSHITHA        V A      A      O      O     B+
# 5     9.10E+11               ANU          M      A     A+      O      A
# 6     9.10E+11        ARULSELVAN          M     B+      O      O      A
# 7     9.10E+11              ARUN          S     B+     A+     A+     B+
# 8     9.10E+11        ARUN KUMAR          M      A     A+     A+      A
# 9     9.10E+11      BALAKRISHNAN          B      A      O      O      A
# 10    9.10E+11      DEEPTHIPRIYA          R     A+      O      O     A+
# 11    9.10E+11         DHARSHIKA        R S     A+     A+     A+     A+
# ...

# %%
import numpy as np
df=pd.DataFrame(data)
df["GP2"]=np.where((df.Grade2=='U'),
           4,np.where((df.Grade2=='B'),
                    6,np.where((df.Grade2=='B+'),
                    7,np.where((df.Grade2=='A'),
                     8,np.where((df.Grade2=='A+'),
                      9,np.where((df.Grade2=='O'),
                      10,5))))))

# %%
import numpy as np
df=pd.DataFrame(data)
df["GP3"]=np.where((df.Grade3=='U'),
           4,np.where((df.Grade3=='B'),
                    6,np.where((df.Grade3=='B+'),
                    7,np.where((df.Grade3=='A'),
                     8,np.where((df.Grade3=='A+'),
                      9,np.where((df.Grade3=='O'),
                      10,5))))))

# %%
df=pd.DataFrame(data)
df["GP4"]=np.where((df.Grade4=='U'),
           4,np.where((df.Grade4=='B'),
                    6,np.where((df.Grade4=='B+'),
                    7,np.where((df.Grade4=='A'),
                     8,np.where((df.Grade4=='A+'),
                      9,np.where((df.Grade4=='O'),
                      10,5))))))

# %%
df=pd.DataFrame(data)
df["GP5"]=np.where((df.Grade5=='U'),
           4,np.where((df.Grade5=='B'),
                    6,np.where((df.Grade5=='B+'),
                    7,np.where((df.Grade5=='A'),
                     8,np.where((df.Grade5=='A+'),
                      9,np.where((df.Grade5=='O'),
                      10,5))))))

# %%
df=pd.DataFrame(data)
df["GP6"]=np.where((df.Grade6=='U'),
           4,np.where((df.Grade6=='B'),
                    6,np.where((df.Grade6=='B+'),
                    7,np.where((df.Grade6=='A'),
                     8,np.where((df.Grade6=='A+'),
                      9,np.where((df.Grade6=='O'),
                      10,5))))))

# %%
df=pd.DataFrame(data)
df["GP7"]=np.where((df.Grade7=='U'),
           4,np.where((df.Grade7=='B'),
                    6,np.where((df.Grade7=='B+'),
                    7,np.where((df.Grade7=='A'),
                     8,np.where((df.Grade7=='A+'),
                      9,np.where((df.Grade7=='O'),
                      10,5))))))

# %%
df=pd.DataFrame(data)
df["GP8"]=np.where((df.Grade8=='U'),
           4,np.where((df.Grade8=='B'),
                    6,np.where((df.Grade8=='B+'),
                    7,np.where((df.Grade8=='A'),
                     8,np.where((df.Grade8=='A+'),
                      9,np.where((df.Grade8=='O'),
                      10,5))))))

# %%
df=pd.DataFrame(data)
df["GP9"]=np.where((df.Grade9=='U'),
           4,np.where((df.Grade9=='B'),
                    6,np.where((df.Grade9=='B+'),
                    7,np.where((df.Grade9=='A'),
                     8,np.where((df.Grade9=='A+'),
                      9,np.where((df.Grade9=='O'),
                      10,5))))))

# %%
data.head(53)
# Out:
# ...
#    Reg. Number        Stud. Name Unnamed: 2 Grade1 Grade2 Grade3 Grade4  \
# 0     9.10E+11    AATHAVAJAYANTH        A S     A+      O      O      B
# 1     9.10E+11           ABINAYA          P      B      A      O     B+
# 2     9.10E+11       AJITH KUMAR          K     A+      O      O     A+
# 3     9.10E+11           AKSHAYA          S      A      O      O      A
# 4     9.10E+11          AKSHITHA        V A      A      O      O     B+
# 5     9.10E+11               ANU          M      A     A+      O      A
# 6     9.10E+11        ARULSELVAN          M     B+      O      O      A
# 7     9.10E+11              ARUN          S     B+     A+     A+     B+
# 8     9.10E+11        ARUN KUMAR          M      A     A+     A+      A
# 9     9.10E+11      BALAKRISHNAN          B      A      O      O      A
# 10    9.10E+11      DEEPTHIPRIYA          R     A+      O      O     A+
# 11    9.10E+11         DHARSHIKA        R S     A+     A+     A+     A+
# ...

# %%
df=pd.DataFrame(data)
data.insert(21,"CGPA",((df["GP1"]*4)+(df["GP2"]*4)+(df["GP3"]*3)+(df["GP4"]*3)+(df["GP5"]*3)+(df["GP6"]*3)+(df["GP7"]*2)+(df["GP8"]*2)+(df["GP9"]*2))/26)
data.head(44)
# Out:
# ...
#    Reg. Number        Stud. Name Unnamed: 2 Grade1 Grade2 Grade3 Grade4  \
# 0     9.10E+11    AATHAVAJAYANTH        A S     A+      O      O      B
# 1     9.10E+11           ABINAYA          P      B      A      O     B+
# 2     9.10E+11       AJITH KUMAR          K     A+      O      O     A+
# 3     9.10E+11           AKSHAYA          S      A      O      O      A
# 4     9.10E+11          AKSHITHA        V A      A      O      O     B+
# 5     9.10E+11               ANU          M      A     A+      O      A
# 6     9.10E+11        ARULSELVAN          M     B+      O      O      A
# 7     9.10E+11              ARUN          S     B+     A+     A+     B+
# 8     9.10E+11        ARUN KUMAR          M      A     A+     A+      A
# 9     9.10E+11      BALAKRISHNAN          B      A      O      O      A
# 10    9.10E+11      DEEPTHIPRIYA          R     A+      O      O     A+
# 11    9.10E+11         DHARSHIKA        R S     A+     A+     A+     A+
# ...
